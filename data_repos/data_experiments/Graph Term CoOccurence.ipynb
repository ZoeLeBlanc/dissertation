# %%
import altair as alt
import pandas as pd
import glob, os
import spacy
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.manifold import MDS
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_selection import chi2
import gensim
from gensim.corpora import Dictionary
from gensim.similarities import MatrixSimilarity
from gensim.models import ldamodel, doc2vec, LsiModel
import nltk
import string
from nltk.corpus import stopwords
from nltk.util import ngrams
import networkx as nx
import matplotlib.pyplot as plt
from networkx.readwrite import json_graph
alt.renderers.enable('notebook')
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
nltk_df = pd.read_csv('Arab_Observer_Tokenized_Distributions.csv')
len(nltk_df.index)
# Out:
# 11183

# %%
data = nltk_df[nltk_df['tokenized'].str.contains('anti') == True]
data = data[nltk_df['tokenized'].str.contains('colonialism') == True]
data = data[nltk_df['tokenized'].str.contains('revolution') == True]
data.tokenized = data.tokenized.str.replace('\d+', '')
# data.sort_values(by=['htrc_vol'])
    
# def create_matrix(ents):
#     count_model = CountVectorizer(ngram_range=(1,1)) # default unigram model
#     X = count_model.fit_transform(ents)
#     Xc = (X.T * X)
#     # Xc.setdiag(0)
#     vocab = count_model.vocabulary_
#     vocab2 = {y:x for x,y in vocab.items()}
#     return create_network(Xc, vocab2)
    
# def create_network(matrix, vocab):
#     G = nx.from_scipy_sparse_matrix(matrix)
#     H = nx.relabel_nodes(G, vocab)
#     df = nx.to_pandas_edgelist(H)
#     df = df[df['source'].str.isnumeric() == False]
#     df = df[df['target'].str.isnumeric() == False]
#     df['terms'] = df['source'] + '_' + df['target']
#     # df = df.drop(columns = ['source', 'target'])
#     return df
# df = create_matrix(data.tokenized[0:100])
# Out:
# /Users/zgl3n/.local/share/virtualenvs/htrc-BT75Zmf5/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/zgl3n/.local/share/virtualenvs/htrc-BT75Zmf5/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(data.tokenized.str.split().str.len())
# Out:
# 210      420
# 412      530
# 928      544
# 1067     561
# 1285     548
# 1621     544
# 1693     279
# 1810     454
# 1984     443
# 2661     548
# 2842     397
# 3248     459
# 3576     544
# 4007     441
# 4045     406
# 4046     462
# 4120     458
# 4122     460
# 4155     565
# 4673     527
# 4951     499
# 5625     430
# 5716     463
# 5721     519
# 5909     287
# 5940     630
# 6069     677
# 6279     624
# 6280     470
# 6380     416
#         ...
# 8054     512
# 8096     251
# 8518     353
# 8917     319
# 9055     581
# 9065     611
# 9170     553
# 9204     292
# 9298     404
# 9384     416
# 9534     221
# 9567     581
# 9628     652
# 9786     335
# 9843     442
# 9960     547
# 10073    404
# 10306    395
# 10512    615
# 10615    519
# 10695    525
# 10764    485
# 10864    467
# 10928    456
# 10962    300
# 10968    492
# 11081    390
# 11097    523
# 11126    404
# 11133    517
# Name: tokenized, Length: 74, dtype: int64

# %%
print(df)
# Out:
#                      source              target  weight  \
# 4197                    00u             applied       1
# 4198                    00u             country       1
# 4199                    00u                  ed       1
# 4200                    00u         established       1
# 4201                    00u             foreign       1
# 4202                    00u             general       5
# 4203                    00u             include       1
# 4204                    00u                last       1
# 4205                    00u                lead       1
# 4206                    00u              living       1
# 4207                    00u                mber       1
# 4208                    00u             meeting       2
# 4209                    00u             members       1
# 4210                    00u                must       1
# 4211                    00u            national       2
# 4212                    00u            ordinary       1
# 4213                    00u        organisation       2
# 4214                    00u              people       2
# 4215                    00u           political       1
# 4216                    00u               power       1
# 4217                    00u              report       1
# 4218                    00u              sector       1
# 4219                    00u            services       1
# 4220                    00u               state       1
# 4221                    00u                used       1
# 4222                    00u           wednesday       1
# 4223                    00u                week       4
# 4224                    00u              within       1
# 4225                    00u                arab       6
# 4227                    00u               abdel       1
# ...                     ...                 ...     ...
# 3125127                yuri                yuri       1
# 3125128              yussef              yussef       1
# 3125129                  za             zobeiri       1
# 3125130                  za                  za       2
# 3125131              zaabal              zaabal       1
# 3125132           zahreddin           zakreddin       1
# 3125133           zahreddin           zahreddin      10
# 3125134           zahreddin                zone       3
# 3125135             zakaria             zakaria       1
# 3125136                zakl                zakl       1
# 3125137           zakreddin           zakreddin       1
# 3125138           zalovesky           zalovesky       1
# 3125139            zanzibar            zanzibar       4
# 3125140             zarissa             zarissa       1
# 3125141             zarissa               zirhe       1
# 3125142               zeine               zeine       1
# 3125143                zion                zion       1
# 3125144              zionii  zionistreactionary       1
# 3125145              zionii              zionii       1
# 3125146             zionism             zionism      10
# 3125147             zionism             zionist       3
# 3125148             zionist             zionist      11
# 3125149  zionistreactionary  zionistreactionary       1
# 3125150               zirhe               zirhe       1
# 3125151             zobeiri             zobeiri       1
# 3125152              zoheir              zoheir       1
# 3125153               zokak               zokak       1
# 3125154                zone                zone       2
# 3125155               zones               zones       1
# 3125156                zvai                zvai       1
#
#                                          terms
# 4197                               00u_applied
# 4198                               00u_country
# 4199                                    00u_ed
# 4200                           00u_established
# 4201                               00u_foreign
# 4202                               00u_general
# 4203                               00u_include
# 4204                                  00u_last
# 4205                                  00u_lead
# 4206                                00u_living
# 4207                                  00u_mber
# 4208                               00u_meeting
# 4209                               00u_members
# 4210                                  00u_must
# 4211                              00u_national
# 4212                              00u_ordinary
# 4213                          00u_organisation
# 4214                                00u_people
# 4215                             00u_political
# 4216                                 00u_power
# 4217                                00u_report
# 4218                                00u_sector
# 4219                              00u_services
# 4220                                 00u_state
# 4221                                  00u_used
# 4222                             00u_wednesday
# 4223                                  00u_week
# 4224                                00u_within
# 4225                                  00u_arab
# 4227                                 00u_abdel
# ...                                        ...
# 3125127                              yuri_yuri
# 3125128                          yussef_yussef
# 3125129                             za_zobeiri
# 3125130                                  za_za
# 3125131                          zaabal_zaabal
# 3125132                    zahreddin_zakreddin
# 3125133                    zahreddin_zahreddin
# 3125134                         zahreddin_zone
# 3125135                        zakaria_zakaria
# 3125136                              zakl_zakl
# 3125137                    zakreddin_zakreddin
# 3125138                    zalovesky_zalovesky
# 3125139                      zanzibar_zanzibar
# 3125140                        zarissa_zarissa
# 3125141                          zarissa_zirhe
# 3125142                            zeine_zeine
# 3125143                              zion_zion
# 3125144              zionii_zionistreactionary
# 3125145                          zionii_zionii
# 3125146                        zionism_zionism
# 3125147                        zionism_zionist
# 3125148                        zionist_zionist
# 3125149  zionistreactionary_zionistreactionary
# 3125150                            zirhe_zirhe
# 3125151                        zobeiri_zobeiri
# 3125152                          zoheir_zoheir
# 3125153                            zokak_zokak
# 3125154                              zone_zone
# 3125155                            zones_zones
# 3125156                              zvai_zvai
#
# [2966158 rows x 4 columns]
